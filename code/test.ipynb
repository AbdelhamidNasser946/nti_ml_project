# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"D:\NTI\project\data\fraud.csv")

# %%
df
# Out:
#       transaction_amount  hour_of_day  is_weekend  num_items  customer_age  \
# 0             161.363691          3.0         0.0        2.0     18.000000
# 1             116.202851          1.0         1.0        4.0     26.285818
# 2               1.000000          2.0         0.0        5.0     18.000000
# 3              48.780618          2.0         0.0        3.0     44.471190
# 4                    NaN          3.0         0.0        4.0     38.733609
# ...                  ...          ...         ...        ...           ...
# 6995           60.899825          3.0         0.0        2.0     23.866277
# 6996           97.935366          2.0         0.0        0.0     26.703634
# 6997           78.557604          3.0         0.0        4.0     61.925540
# 6998           65.029273          2.0         0.0        3.0     18.947720
# 6999          110.146151          NaN         0.0        1.0     30.983931
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
missing_percentage = (df.isna().mean() * 100).sort_values(ascending=False).round(2)
missing_percentage[missing_percentage > 0]
# Out:
# transaction_amount       8.0
# hour_of_day              5.0
# is_weekend               2.0
# num_items                3.0
# customer_age            12.0
# prev_transactions        7.0
# distance_from_home      10.0
# device_type              4.0
# network_quality          9.0
# is_first_transaction     3.0
# store_type               2.0
# velocity_score          15.0
# is_fraud                 0.0
# dtype: float64
